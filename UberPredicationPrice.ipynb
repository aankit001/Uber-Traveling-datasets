# %% [markdown]
# #Getting Start with Import some essentail machine learning Library
# and the link for the data is: https://drive.google.com/drive/folders/1fxAVH6l2h9wLMRRRMp668aiK_-x2uNGp

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
rides_df = pd.read_csv('/content/cab_rides (1).csv')
weather_df = pd.read_csv('/content/weather.csv')

# %% [markdown]
# # view the data

# %% [markdown]
# ## View the rides Dataset

# %%
rides_df
# Out:
#        distance cab_type  ...                            product_id          name
# 0          0.44     Lyft  ...                             lyft_line        Shared
# 1          0.44     Lyft  ...                          lyft_premier           Lux
# 2          0.44     Lyft  ...                                  lyft          Lyft
# 3          0.44     Lyft  ...                           lyft_luxsuv  Lux Black XL
# 4          0.44     Lyft  ...                             lyft_plus       Lyft XL
# ...         ...      ...  ...                                   ...           ...
# 49232      1.74     Lyft  ...                                  lyft          Lyft
# 49233      1.74     Lyft  ...                              lyft_lux     Lux Black
# 49234      1.74     Lyft  ...                             lyft_line        Shared
# 49235      2.80     Uber  ...  6c84fd89-3f11-4782-9b50-97c468b19529         Black
# ...

# %%
rides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49237 entries, 0 to 49236
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   distance          49237 non-null  float64
#  1   cab_type          49237 non-null  object
#  2   time_stamp        49237 non-null  int64
#  3   destination       49237 non-null  object
#  4   source            49237 non-null  object
#  5   price             45394 non-null  float64
#  6   surge_multiplier  49237 non-null  float64
#  7   id                49237 non-null  object
#  8   product_id        49237 non-null  object
#  9   name              49236 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.8+ MB

# %% [markdown]
# ## View the Weather Dataset

# %%
weather_df
# Out:
#        temp                 location  clouds  ...  time_stamp  humidity   wind
# 0     42.42                 Back Bay    1.00  ...  1545003901      0.77  11.25
# 1     42.43              Beacon Hill    1.00  ...  1545003901      0.76  11.32
# 2     42.50        Boston University    1.00  ...  1545003901      0.76  11.07
# 3     42.11                   Fenway    1.00  ...  1545003901      0.77  11.09
# 4     43.13       Financial District    1.00  ...  1545003901      0.75  11.49
# ...     ...                      ...     ...  ...         ...       ...    ...
# 6271  44.72            North Station    0.89  ...  1543819974      0.96   1.52
# 6272  44.85  Northeastern University    0.88  ...  1543819974      0.96   1.54
# 6273  44.82            South Station    0.89  ...  1543819974      0.96   1.54
# 6274  44.78         Theatre District    0.89  ...  1543819974      0.96   1.54
# 6275  44.69                 West End    0.89  ...  1543819974      0.96   1.52
#
# [6276 rows x 8 columns]

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6276 entries, 0 to 6275
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        6276 non-null   float64
#  1   location    6276 non-null   object
#  2   clouds      6276 non-null   float64
#  3   pressure    6276 non-null   float64
#  4   rain        894 non-null    float64
#  5   time_stamp  6276 non-null   int64
#  6   humidity    6276 non-null   float64
#  7   wind        6276 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 392.4+ KB

# %% [markdown]
# # Clean the Value

# %% [markdown]
# ## Cleaning Rides dataset

# %%
rides_df.isna().sum()
# Out:
# distance               0
# cab_type               0
# time_stamp             0
# destination            0
# source                 0
# price               3843
# surge_multiplier       0
# id                     0
# product_id             0
# name                   1
# dtype: int64

# %%
# dropping the null value from teh datasets by row wise
rides_df = rides_df.dropna(axis=0).reset_index(drop=True)
rides_df
# Out:
#        distance cab_type  ...                            product_id          name
# 0          0.44     Lyft  ...                             lyft_line        Shared
# 1          0.44     Lyft  ...                          lyft_premier           Lux
# 2          0.44     Lyft  ...                                  lyft          Lyft
# 3          0.44     Lyft  ...                           lyft_luxsuv  Lux Black XL
# 4          0.44     Lyft  ...                             lyft_plus       Lyft XL
# ...         ...      ...  ...                                   ...           ...
# 45388      1.74     Lyft  ...                          lyft_premier           Lux
# 45389      1.74     Lyft  ...                                  lyft          Lyft
# 45390      1.74     Lyft  ...                              lyft_lux     Lux Black
# 45391      1.74     Lyft  ...                             lyft_line        Shared
# ...

# %%
# Check if their any null value is present or not
rides_df.isna().sum()
# Out:
# distance            0
# cab_type            0
# time_stamp          0
# destination         0
# source              0
# price               0
# surge_multiplier    0
# id                  0
# product_id          0
# name                0
# dtype: int64

# %% [markdown]
# ## Cleaning Weather Dataframe

# %%
weather_df
# Out:
#        temp                 location  clouds  ...  time_stamp  humidity   wind
# 0     42.42                 Back Bay    1.00  ...  1545003901      0.77  11.25
# 1     42.43              Beacon Hill    1.00  ...  1545003901      0.76  11.32
# 2     42.50        Boston University    1.00  ...  1545003901      0.76  11.07
# 3     42.11                   Fenway    1.00  ...  1545003901      0.77  11.09
# 4     43.13       Financial District    1.00  ...  1545003901      0.75  11.49
# ...     ...                      ...     ...  ...         ...       ...    ...
# 6271  44.72            North Station    0.89  ...  1543819974      0.96   1.52
# 6272  44.85  Northeastern University    0.88  ...  1543819974      0.96   1.54
# 6273  44.82            South Station    0.89  ...  1543819974      0.96   1.54
# 6274  44.78         Theatre District    0.89  ...  1543819974      0.96   1.54
# 6275  44.69                 West End    0.89  ...  1543819974      0.96   1.52
#
# [6276 rows x 8 columns]

# %%
weather_df.isna().sum()
# Out:
# temp             0
# location         0
# clouds           0
# pressure         0
# rain          5382
# time_stamp       0
# humidity         0
# wind             0
# dtype: int64

# %%
# Drop the Null value of the dataset
weather_df = weather_df.fillna(0)

# %%
# Check their any null value is present or not 
weather_df.isna().sum()
# Out:
# temp          0
# location      0
# clouds        0
# pressure      0
# rain          0
# time_stamp    0
# humidity      0
# wind          0
# dtype: int64

# %% [markdown]
# ## Creating Average DataFrame for the weather

# %%
weather_df
# Out:
#        temp                 location  clouds  ...  time_stamp  humidity   wind
# 0     42.42                 Back Bay    1.00  ...  1545003901      0.77  11.25
# 1     42.43              Beacon Hill    1.00  ...  1545003901      0.76  11.32
# 2     42.50        Boston University    1.00  ...  1545003901      0.76  11.07
# 3     42.11                   Fenway    1.00  ...  1545003901      0.77  11.09
# 4     43.13       Financial District    1.00  ...  1545003901      0.75  11.49
# ...     ...                      ...     ...  ...         ...       ...    ...
# 6271  44.72            North Station    0.89  ...  1543819974      0.96   1.52
# 6272  44.85  Northeastern University    0.88  ...  1543819974      0.96   1.54
# 6273  44.82            South Station    0.89  ...  1543819974      0.96   1.54
# 6274  44.78         Theatre District    0.89  ...  1543819974      0.96   1.54
# 6275  44.69                 West End    0.89  ...  1543819974      0.96   1.52
#
# [6276 rows x 8 columns]

# %%
# Create avg value of location
weather_df.groupby('location').mean()
# Out:
#                               temp    clouds  ...  humidity      wind
# location                                      ...
# Back Bay                 39.082122  0.678432  ...  0.764073  6.778528
# Beacon Hill              39.047285  0.677801  ...  0.765048  6.810325
# Boston University        39.047744  0.679235  ...  0.763786  6.692180
# Fenway                   38.964379  0.679866  ...  0.767266  6.711721
# Financial District       39.410822  0.676730  ...  0.754837  6.860019
# Haymarket Square         39.067897  0.676711  ...  0.764837  6.843193
# North End                39.090841  0.676730  ...  0.764054  6.853117
# North Station            39.035315  0.676998  ...  0.765545  6.835755
# Northeastern University  38.975086  0.678317  ...  0.767648  6.749426
# South Station            39.394092  0.677495  ...  0.755468  6.848948
# Theatre District         38.986711  0.677763  ...  0.767992  6.834302
# West End                 38.983403  0.677247  ...  0.767266  6.816233
#
# ...

# %%
avg_weather_df = weather_df.groupby('location').mean().reset_index(drop=False)
avg_weather_df = avg_weather_df.drop('time_stamp', axis=1)
avg_weather_df
# Out:
#                    location       temp    clouds  ...      rain  humidity      wind
# 0                  Back Bay  39.082122  0.678432  ...  0.007925  0.764073  6.778528
# 1               Beacon Hill  39.047285  0.677801  ...  0.008297  0.765048  6.810325
# 2         Boston University  39.047744  0.679235  ...  0.007738  0.763786  6.692180
# 3                    Fenway  38.964379  0.679866  ...  0.007343  0.767266  6.711721
# 4        Financial District  39.410822  0.676730  ...  0.008563  0.754837  6.860019
# 5          Haymarket Square  39.067897  0.676711  ...  0.008660  0.764837  6.843193
# 6                 North End  39.090841  0.676730  ...  0.008644  0.764054  6.853117
# 7             North Station  39.035315  0.676998  ...  0.008649  0.765545  6.835755
# 8   Northeastern University  38.975086  0.678317  ...  0.007358  0.767648  6.749426
# 9             South Station  39.394092  0.677495  ...  0.008310  0.755468  6.848948
# ...

# %% [markdown]
# # Merging the data

# %%
rides_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45393 entries, 0 to 45392
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   distance          45393 non-null  float64
#  1   cab_type          45393 non-null  object
#  2   time_stamp        45393 non-null  int64
#  3   destination       45393 non-null  object
#  4   source            45393 non-null  object
#  5   price             45393 non-null  float64
#  6   surge_multiplier  45393 non-null  float64
#  7   id                45393 non-null  object
#  8   product_id        45393 non-null  object
#  9   name              45393 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
# First we need to change the columns name of the weather dataset so that we merge it.
source_weather_df = avg_weather_df.rename(
    columns={
        'location':'source',
        'temp' : 'source_temp',
        'clouds': 'source_clouds',
        'pressure': 'source_pressure',
        'rain': 'sourece_rain',
        'humudity': 'source_humudity',
        'wind': 'source_wind'
    }
)

# %%
source_weather_df
# Out:
#                      source  source_temp  ...  humidity  source_wind
# 0                  Back Bay    39.082122  ...  0.764073     6.778528
# 1               Beacon Hill    39.047285  ...  0.765048     6.810325
# 2         Boston University    39.047744  ...  0.763786     6.692180
# 3                    Fenway    38.964379  ...  0.767266     6.711721
# 4        Financial District    39.410822  ...  0.754837     6.860019
# 5          Haymarket Square    39.067897  ...  0.764837     6.843193
# 6                 North End    39.090841  ...  0.764054     6.853117
# 7             North Station    39.035315  ...  0.765545     6.835755
# 8   Northeastern University    38.975086  ...  0.767648     6.749426
# 9             South Station    39.394092  ...  0.755468     6.848948
# 10         Theatre District    38.986711  ...  0.767992     6.834302
# 11                 West End    38.983403  ...  0.767266     6.816233
#
# [12 rows x 7 columns]

# %%
# Create destination part so well
dest_weather_df = avg_weather_df.rename(
    columns={
        'location':'destination',
        'temp' : 'dest_temp',
        'clouds': 'dest_clouds',
        'pressure': 'dest_pressure',
        'rain': 'dest_rain',
        'humudity': 'dest_humudity',
        'wind': 'dest_wind'
    }
)

# %%
dest_weather_df
# Out:
#                 destination  dest_temp  ...  humidity  dest_wind
# 0                  Back Bay  39.082122  ...  0.764073   6.778528
# 1               Beacon Hill  39.047285  ...  0.765048   6.810325
# 2         Boston University  39.047744  ...  0.763786   6.692180
# 3                    Fenway  38.964379  ...  0.767266   6.711721
# 4        Financial District  39.410822  ...  0.754837   6.860019
# 5          Haymarket Square  39.067897  ...  0.764837   6.843193
# 6                 North End  39.090841  ...  0.764054   6.853117
# 7             North Station  39.035315  ...  0.765545   6.835755
# 8   Northeastern University  38.975086  ...  0.767648   6.749426
# 9             South Station  39.394092  ...  0.755468   6.848948
# 10         Theatre District  38.986711  ...  0.767992   6.834302
# 11                 West End  38.983403  ...  0.767266   6.816233
#
# [12 rows x 7 columns]

# %%
# Merging the dataframe
data = rides_df\
    .merge(source_weather_df, on='source')\
    .merge(dest_weather_df, on='destination')
data
# Out:
#        distance cab_type     time_stamp  ... dest_rain humidity_y  dest_wind
# 0          0.44     Lyft  1544952607890  ...  0.008649   0.765545   6.835755
# 1          0.44     Lyft  1543284023677  ...  0.008649   0.765545   6.835755
# 2          0.44     Lyft  1543366822198  ...  0.008649   0.765545   6.835755
# 3          0.44     Lyft  1543553582749  ...  0.008649   0.765545   6.835755
# 4          0.44     Lyft  1543463360223  ...  0.008649   0.765545   6.835755
# ...         ...      ...            ...  ...       ...        ...        ...
# 45388      1.03     Lyft  1543416068103  ...  0.008660   0.764837   6.843193
# 45389      1.03     Lyft  1543413910199  ...  0.008660   0.764837   6.843193
# 45390      1.03     Lyft  1543519677649  ...  0.008660   0.764837   6.843193
# 45391      1.03     Lyft  1543463588092  ...  0.008660   0.764837   6.843193
# 45392      1.03     Lyft  1544785803665  ...  0.008660   0.764837   6.843193
#
# [45393 rows x 22 columns]

# %% [markdown]
# # Preprocessing the datasets

# %%
# Create function for the dummy variables with the help of one hot encoding
def onehot_encode(df , columns , prefix):
  df = df.copy()
  dummies = pd.get_dummies(df[columns],prefix)
  df = pd.concat([df,dummies],axis=1)
  df = df.drop(columns,axis=1)
  return df

# %%
def preprocess_inputs(df):
    df = df.copy()
    
    # Drop id column
    df = df.drop('id', axis=1)
    
    # Binary encode cab_type column
    df['cab_type'] = df['cab_type'].replace({'Lyft': 0, 'Uber': 1})
    
    # One-hot encode remaining categorical columns
    for column, prefix in [('destination', "dest"), ('source', "src"), ('product_id', "pid"), ('name', "nm")]:
        df = onehot_encode(df, column, prefix)
    
    # Split df into X and y
    y = df['price']
    X = df.drop('price', axis=1)
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)
    
    # Scale X
    scaler = StandardScaler()
    scaler.fit(X_train)
    
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(data)
X_train
# Out:
#        distance  cab_type  time_stamp  ...  nm_UberX  nm_UberXL    nm_WAV
# 0     -1.264387 -1.010408   -0.278275  ... -0.302757  -0.303067 -0.302013
# 1      0.530986  0.989699   -0.885685  ... -0.302757  -0.303067  3.311114
# 2     -1.149413 -1.010408   -0.804815  ... -0.302757  -0.303067 -0.302013
# 3      0.557518  0.989699   -0.646029  ...  3.302979  -0.303067 -0.302013
# 4      0.760935  0.989699    1.355210  ... -0.302757   3.299605 -0.302013
# ...         ...       ...         ...  ...       ...        ...       ...
# 31770 -0.512630  0.989699   -0.538273  ...  3.302979  -0.303067 -0.302013
# 31771  0.849377 -1.010408    1.457285  ... -0.302757  -0.303067 -0.302013
# 31772  0.840533 -1.010408   -0.694009  ... -0.302757  -0.303067 -0.302013
# 31773 -0.353435  0.989699    1.096080  ... -0.302757  -0.303067 -0.302013
# 31774  0.628272  0.989699    1.141882  ... -0.302757  -0.303067 -0.302013
#
# [31775 rows x 64 columns]

# %%
y_train
# Out:
# 44172    16.5
# 12926     9.5
# 44245    22.5
# 23248    10.5
# 31541    16.5
#          ...
# 43723     9.5
# 32511    19.5
# 5192     19.5
# 12172     9.0
# 33003    29.5
# Name: price, Length: 31775, dtype: float64

# %% [markdown]
# #Training the dataset

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Test the dataset on the testdatasets

# %%
score = model.score(X_test, y_test)
score
# Out:
# 0.9308687867617759
